# %%
import matplotlib.pyplot as pl
# %matplotlib inline

# %%
pl.plot([1,2,3,4])

# %%
x = [1,2,3,4,5,6]
y = [2,3,2,1,6,10]

fig, ax = pl.subplots()
ax.scatter(x,y)

# %%
data = [1,1,2,2,1,2,3,3,2,3,1,3,2],
fig, ax = pl.subplots()
ax.hist(data, bins=3)
ax.set_title("Exemplo de histograma")
ax.set_xlabel("Rótulo X")
ax.set_ylabel("Rótulo Y")
# Out:
# Text(0, 0.5, 'Rótulo Y')

# %%
import csv
filename = "files/cars.csv"
with open(filename) as file:
    spamreader = csv.DictReader(file)
    # lista = []
    # for linha in spamreader:
    #     lista.append(linha)
    lista = list(spamreader)

    hp = [int(linha["Horsepower"]) for linha in lista]
    torque = [int(linha["Torque"]) for linha in lista]
    fuel_city_mpg = [int(linha["Fuel City mpg"]) for linha in lista]

    import matplotlib.pyplot as plt
    fig, ax = plt.subplots()
    ax.scatter(hp, torque, c=fuel_city_mpg, alpha=.05)

# %%
import random

def roll_dice():
    return random.randint(1,6) + random.randint(1,6)

# quanto maior a quantidade de interações, mais o histograma se aproxima de uma forma "triangular" ...
# ... para isso, basta adicionar alguns zeros e visualizar o resultado.
lista = [roll_dice() for i in range(500)]

import matplotlib.pyplot as plt
ax, fig = plt.subplots()
fig.hist(lista, bins=11)
# Out:
# (array([16., 32., 43., 55., 61., 75., 73., 59., 43., 30., 13.]),
#  array([ 2.        ,  2.90909091,  3.81818182,  4.72727273,  5.63636364,
#          6.54545455,  7.45454545,  8.36363636,  9.27272727, 10.18181818,
#         11.09090909, 12.        ]),
#  <BarContainer object of 11 artists>)
